# %% [markdown]
# <a href="https://colab.research.google.com/github/hamohseni/MetNumUN2021I/blob/main/Lab5/hamohseniLab5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 4, 8)
        self.SetEndDate(2021, 4, 1)
        self.SetCash(100300)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("IWM", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("IWM", 100)
            self.Debug(str(self.Portfolio["IWM"].AveragePrice))

# %% [markdown]
# ![1.JPG](data:image/jpeg;base64,...)![2.JPG](data:image/jpeg;base64,...)

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 4, 8)
        self.SetEndDate(2021, 4, 1)
        self.SetCash(100300)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("AAPL", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("AAPL", 100)
            self.Debug(str(self.Portfolio["AAPL"].AveragePrice))

# %% [markdown]
# ![3.JPG](data:image/jpeg;base64,...)![4.JPG](data:image/jpeg;base64,...)

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 4, 8)
        self.SetEndDate(2021, 4, 1)
        self.SetCash(100300)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("FUBO", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("FUBO", 100)
            self.Debug(str(self.Portfolio["FUBO"].AveragePrice))

# %% [markdown]
# ![5.JPG](data:image/jpeg;base64,...)![6.JPG](data:image/jpeg;base64,...)

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 4, 8)
        self.SetEndDate(2021, 4, 1)
        self.SetCash(100300)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("GE", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("GE", 100)
            self.Debug(str(self.Portfolio["GE"].AveragePrice))

# %% [markdown]
# ![7.JPG](data:image/jpeg;base64,...)![8.JPG](data:image/jpeg;base64,...)

# %%
class BootCampTask(QCAlgorithm):

    def Initialize(self):
        self.SetStartDate(2018, 4, 8)
        self.SetEndDate(2021, 4, 1)
        self.SetCash(100300)

        #1,2. Select IWM minute resolution data and set it to Raw normalization mode
        self.iwm = self.AddEquity("PLTR", Resolution.Minute)
        self.iwm.SetDataNormalizationMode(DataNormalizationMode.Raw)

    def OnData(self, data):

        #3. Place an order for 100 shares of IWM and print the average fill price
        #4. Debug the AveragePrice of IWM
        if not self.Portfolio.Invested:
            self.MarketOrder("PLTR", 100)
            self.Debug(str(self.Portfolio["PLTR"].AveragePrice))

# %% [markdown]
# ![9.JPG](data:image/jpeg;base64,...)![10.JPG](data:image/jpeg;base64,...)
