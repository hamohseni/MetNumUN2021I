# %% [markdown]
# <a href="https://colab.research.google.com/github/hamohseni/MetNumUN2021I/blob/main/IntroductionNumericalAnalysis/hamohseniIntroductionNumericalAnalysisCertificate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![certicado.png](data:image/png;base64,...)![certificado linkedin.png](data:image/png;base64,...)

# %% [markdown]
# https://coursera.org/share/d15f51912e978a17e2cb147b777a76f7
